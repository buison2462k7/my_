# %% [markdown]
# Biến 2 dữ liệu về 1 dòng
# end=" " -> ko được xuống dòng -> nên B được in ngay sau A
# tùy kí tự giữa "" trong end="" sẽ chèn vô giữa A và B

# %%
print("Hello", end = "")
print("World")
# Out:
# Hello?World

# %%
name = input("Nhập tên của bạn: ")
print("Hello" , name , "!")
age = int(input("Nhập tuổi của bạn: "))
print("Tuổi của tôi năm nay là: " , age , "tuổi")
born = int(input("day"))
born1 = int(input("month"))
born2 = int(input("year"))
print("Ngày Sinh: " ,born,born1,born2 , sep="/")
# Out:
# Hello Sơn !
# Tuổi của tôi năm nay là:  19 tuổi
# Ngày Sinh: /24/6/2007

# %%
x=3
y=3.0
z="Bui Thai Son"
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
def cong(a,b):
    return a*b
kq=cong(3,4)
print(kq)
# Out:
# 12

# %%
def tich(a,b):
    return a*b
a= float(input("nhap so a:"))
b= float(input("nhap so b:"))
kq= tich(a,b)
kq = round(kq,1)

print(kq)
# Out:
# 6.3

# %%
a = float(input("số a:"))
b = float(input("số b:"))
def multiply(a,b):
  return a*b
c = round(multiply(a,b),1)
print(c)
# Out:
# 6.7

# %%
print("Hello")
print("World") , sep=''
# Out:
#   Cell In[1], line 2
#     print("World") , sep=''
#                      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
def multiply(a,b):
  return a * b
a= float(input("nhap so a:"))
b= float(input("nhap so b:"))
print(round(multiply(a,b),1))
# Out:
# 9.9

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %%
x = 5
print(id(x))
# Out:
# 140736486941944

# %%
x = 3
print(x)
del x
print(x)
print("x")
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 print(x)
#       3 del x
# ----> 4 print(x)
#       5 print("x")
#
# NameError: name 'x' is not defined

# %%
x = str(3)  # x sẽ là '3'
y = int(3)  # y sẽ là 3
z = float(3)  # z sẽ là 3.0
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
# Out:
# 3
# 3
# 3.0
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
def tong(x, y):
    tong = x + y 
    return tong
x = int(input())
y = int(input())
tong(x, y)
# Out:
# 7

# %%
# In ra một chuỗi
print("D25 Hello World!")

# In ra nhiều đối tượng
print("D25", "Hello", "World", sep=" ", end="!\n")

# In ra một tuple
x = ("apple", "banana", "cherry")
print(x)
# Out:
# D25 Hello World!
# D25 Hello World!
# ('apple', 'banana', 'cherry')

# %%
# Yêu cầu người dùng nhập tên
name = input("Nhập tên của bạn: ")
print("Xin chào, " + name + "!")
# Out:
# Xin chào, Son!

# %%
number = input("Nhap cac gia tri: ").split()
print("Cac gia tri da nhap la: ", number)
# Out:
# Cac gia tri da nhap la:  ['2345']

# %%
# Yêu cầu người dùng nhập nhiều giá trị trên một dòng
values = input("Nhập các giá trị, cách nhau bằng khoảng trắng: ").split()
print("Các giá trị bạn đã nhập là:", values)
# Out:
# Các giá trị bạn đã nhập là: ['1', '2', '3']

# %%
a = 21
b = 10

print("a == b:", a == b)   # False
print("a != b:", a != b)   # True
print("a > b:", a > b)     # True
print("a < b:", a < b)     # False
print("a >= b:", a >= b)   # True
print("a <= b:", a <= b)   # False
# Out:
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False

# %%
a = 4
b = 3
print(a "va" , b)
print(f"a and b: {a} and {b}")   # False
print("a or b:", a or b)     # True
print("not a:", not a)       # False
# Out:
#   Cell In[64], line 3
#     print(a "va" , b)
#             ^
# SyntaxError: invalid syntax
