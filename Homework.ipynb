# %%
c=input()
if len(c)==1:
   if "a" <= c <="z" or "A" <= c<= "Z":
     print(f" {c} la ki tu alpha")
   else :
     print(f"{c} ko p ki tu alpha")
# Out:
# 3 ko p ki tu alpha

# %%
c= input()
if len(c)!=1 or not c.isupper():
    print(f"{c} ko hop le")
elif c=="A":
    print(f"{c} ko hop le")
else:
    print(chr(ord(c.lower())-1))
# Out:
# d

# %%
def ham_so(a,b,c):
    return(a,b,c)

a=input().split()
print(a)
# Out:
# ['1', '2', '3']

# %%
c=int(input())
if 0<=c<=9:
 match c:
    case 0:
       print('Khong')
    case 1:
       print('Mot')
    case 2:
       print('Hai')
    case 3:
       print('Ba')
    case 4:
       print('Bon')
    case 5:
       print('Nam')
    case 6:
       print('Sau')
    case 7:
       print('Bay')
    case 8:
       print('Tam')
    case 9:
       print('Chin')
    
 
else:
    print("Khong doc duoc")
# Out:
# Hai

# %%
a,b,c=map(float,input().split())
if a+b<=c or a+c<=b or c+b<=a:
    print(f"{a},{b},{c} khong phai 3 canh tam giac")
elif a==b==c:
    print("La tam giac deu")
elif  (round(a**2+b**2,1)==round(c**2,1) and a==b) or (a**2+c**2==b**2 and a==c) or (b**2+c**2==a**2 and b==c):
    print("La tam giac vuong can")
elif a==b or a==c or b==c:
    print("la tam giac can")
elif a**2+b**2==c**2 or a**2+c**2==b**2 or b**2+c**2==a**2:
    print("La tam giac vuong")
# Out:
# La tam giac vuong can

# %%
a,b,c=map(float,input().split())
if a+b<=c or a+c<=b or c+b<=a:
    print(f"{a},{b},{c} khong phai 3 canh tam giac")
else:
    p=(a+b+c)/2
    Dien_tich=((p-a)*(p-b)*(p-c)*p)**(1/2)
    print(Dien_tich)
# Out:
# 1.0,4.0,7.0 khong phai 3 canh tam giac
